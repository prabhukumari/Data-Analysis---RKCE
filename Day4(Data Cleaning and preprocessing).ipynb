# %% [markdown]
# # Data Analysis using Pandas
#     * Indexing
#     * Grouping
#     * Features
#     * Filtering
#     * Sorting
#     * Statistical
#     * Plotting
#     * Saving

# %% [markdown]
# #### Indexing

# %%
import pandas as pd
data=pd.read_csv("birds.csv")
data
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
#df.loc[rows,col]  #last three col
a=data.loc[:,['tarl','tarw','type']]
a.head()
# Out:
#     tarl  tarw type
# 0  38.70  3.84   SW
# 1  41.50  4.01   SW
# 2  38.31  3.34   SW
# 3  35.78  3.41   SW
# 4  31.88  3.13   SW

# %%
a.tail()
# Out:
#       tarl  tarw type
# 415  21.99  1.15   SO
# 416  23.60  1.15   SO
# 417  22.86  1.21   SO
# 418  25.98  1.24   SO
# 419  21.69  1.05   SO

# %%
#data.iloc[rows,col]  #first 15 rows and last three columns
b=data.iloc[0:16,-3:]
b
# Out:
#      tarl  tarw type
# 0   38.70  3.84   SW
# 1   41.50  4.01   SW
# 2   38.31  3.34   SW
# 3   35.78  3.41   SW
# 4   31.88  3.13   SW
# 5   29.07  2.83   SW
# 6   37.22  3.64   SW
# 7   37.94  3.81   SW
# 8   61.62  4.37   SW
# 9   78.67  6.34   SW
# 10  86.61  6.63   SW
# 11  90.80  4.59   SW
# 12  82.58  5.50   SW
# 13  73.71  4.24   SW
# 14  75.65  3.36   SW
# 15  74.86  3.52   SW

# %%
#col--2,4,6
#rows--1,3,5
a=data.loc[[1,3,5],['huml','ulnal','feml']]
b=data.iloc[1:6:2,2:7:2]

# %% [markdown]
# ### Grouping

# %%
data['type'].unique()
# Out:
# array(['SW', 'W', 'T', 'R', 'P', 'SO'], dtype=object)

# %%
g_birds=data.groupby('type')
g_birds   #group name, record

# %%
for g_n,record in g_birds:
    print(g_n,record)
# Out:
# P       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
g_birds.get_group("P")
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
g_birds.get_group("P").count()
# Out:
# id       38
# huml     38
# humw     38
# ulnal    38
# ulnaw    38
# feml     38
# femw     38
# tibl     38
# tibw     38
# tarl     38
# tarw     38
# type     38
# dtype: int64

# %%
g_birds.get_group("P").shape
# Out:
# (38, 12)

# %%
g1_birds=data.groupby(['type','id'])
g1_birds

# %%
for i,j in g1_birds:
    print(i,j)
# Out:
# ('P', 254)       id   huml  humw  ulnal  ulnaw   feml  femw  tibl  tibw   tarl  tarw type
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.9  1.81  25.22  1.62    P
# ('P', 255)       id  huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 255  255  30.6  2.45   25.9   1.87  32.36   2.1  50.25  1.88  33.58  1.88    P
# ('P', 256)       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw  tarl  tarw type
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98   2.0  33.5  1.93    P
# ('P', 257)       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
#
#     type
# 257    P
# ('P', 258)       id  huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 258  258  45.6  3.35  38.73   3.52  54.45   4.1  83.59  3.72  63.91  2.67    P
# ('P', 259)       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# ...

# %%
g1_birds.get_group(('R',219))
# Out:
#       id   huml  humw   ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 219  219  98.94  7.13  119.72    5.6  74.17   6.3  106.5   5.8  83.13  5.86
#
#     type
# 219    R

# %% [markdown]
# ### Filtering

# %%
#huml>50
data[data["huml"]>50]
# Out:
#       id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 0      0   80.78  6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70  3.84
# 1      1   88.91  6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50  4.01
# 2      2   79.97  6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31  3.34
# 3      3   77.65  5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78  3.41
# 4      4   62.80  4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88  3.13
# ..   ...     ...   ...     ...    ...    ...   ...     ...   ...    ...   ...
# 246  246   90.13  5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55  4.14
# 247  247  100.29  6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03  4.95
# 248  248   96.46  5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95  4.29
# 249  249   93.37  5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30  4.38
# 250  250   99.69  6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23  4.21
#
#     type
# 0     SW
# 1     SW
# ...

# %%
data[data['type']=='SW']
# Out:
#       id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 0      0   80.78  6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70  3.84
# 1      1   88.91  6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50  4.01
# 2      2   79.97  6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31  3.34
# 3      3   77.65  5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78  3.41
# 4      4   62.80  4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88  3.13
# ..   ...     ...   ...     ...    ...    ...   ...     ...   ...    ...   ...
# 111  111  106.23  6.82  104.02   5.07  40.06  4.96  105.34  4.99  57.27  3.20
# 112  112  105.19  7.10   96.85   5.43  37.61  4.43  102.04  4.90  54.78  2.83
# 113  113   76.49  5.36   69.06   4.02  30.07  3.03   72.41  3.71  43.11  2.08
# 114  114   65.66  3.79   61.06   3.35  24.95  2.44   63.76  2.72  40.19  1.89
# 115  115   98.73  6.48   91.69   5.31  35.34  4.02   92.36  4.46  50.53  2.69
#
#     type
# 0     SW
# 1     SW
# ...

# %%
data[((data["huml"]>50) & (data["huml"]>80))]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 0      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# 7      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type
# 0    3.84   SW
# 1    4.01   SW
# 7    3.81   SW
# 8    4.37   SW
# ...

# %%
data[((data['type']=='SW')| (data['type']=='SO'))]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
data[~(data["huml"]>50)]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl   tarw  \
# 26    26  47.51  7.23  32.49   8.26  50.29  5.00  75.20  4.95  22.51  10.73
# 27    27  46.20  7.06  32.73   8.58  52.15  5.11  75.99  4.77  23.24  10.24
# 28    28  41.13  6.71  31.00   7.73  49.51  4.69  71.94  4.54  22.46   9.45
# 53    53  22.63  2.48  27.24   2.03  21.04  2.02  37.69  1.82  21.91   1.72
# 54    54  24.11  2.33  28.05   1.89  22.08  2.05  40.13  1.68  23.73   1.77
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...    ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99   1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60   1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86   1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98   1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69   1.05
#
#     type
# 26    SW
# 27    SW
# 28    SW
# 53    SW
# ...

# %% [markdown]
# ### Sorting

# %%
data
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
data.sort_index() #bydefault index get sorted in ascending order
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
data.sort_index(ascending=False)
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
#
#     type
# 419   SO
# 418   SO
# 417   SO
# 416   SO
# 415   SO
# ...

# %%
data.sort_values(by='huml')
# Out:
#       id    huml   humw   ulnal  ulnaw    feml  femw    tibl   tibw    tarl  \
# 264  264    9.85   2.88   14.73   1.73   16.27  1.22   20.89   1.25    7.77
# 377  377   12.69   1.69   17.44   1.16   11.83  1.03   23.80   0.87   16.97
# 413  413   12.95   1.16   14.09   1.03   13.03  1.03   22.13   0.96   15.19
# 367  367   13.31   1.17   16.47   1.06   12.32  0.93   22.47   0.95   15.97
# 370  370   13.38   1.14   16.51   1.23   12.48  1.12   24.91   0.92   17.55
# ..   ...     ...    ...     ...    ...     ...   ...     ...    ...     ...
# 38    38  272.00  14.86  320.00  10.42   91.60  9.71  132.00  10.23   81.77
# 60    60  300.00  12.48  300.00   8.65   84.05  8.53  178.00   9.61   99.01
# 56    56  310.00  14.40  315.00   9.51   88.77  8.10  180.00   9.45   96.13
# 58    58  420.00  17.84  422.00  11.72  110.54  9.99  237.00  11.03  128.35
# 342  342     NaN    NaN     NaN    NaN   32.54  2.65   55.06   2.81   38.94
#
#      tarw type
# 264  1.23    P
# 377  0.66   SO
# ...

# %%
data.sort_values(by='huml',ascending=False)
# Out:
#       id    huml   humw   ulnal  ulnaw    feml  femw    tibl   tibw    tarl  \
# 58    58  420.00  17.84  422.00  11.72  110.54  9.99  237.00  11.03  128.35
# 56    56  310.00  14.40  315.00   9.51   88.77  8.10  180.00   9.45   96.13
# 60    60  300.00  12.48  300.00   8.65   84.05  8.53  178.00   9.61   99.01
# 38    38  272.00  14.86  320.00  10.42   91.60  9.71  132.00  10.23   81.77
# 39    39  270.00  14.25  310.00  10.90   86.20  9.96  125.76   9.63   79.18
# ..   ...     ...    ...     ...    ...     ...   ...     ...    ...     ...
# 367  367   13.31   1.17   16.47   1.06   12.32  0.93   22.47   0.95   15.97
# 413  413   12.95   1.16   14.09   1.03   13.03  1.03   22.13   0.96   15.19
# 377  377   12.69   1.69   17.44   1.16   11.83  1.03   23.80   0.87   16.97
# 264  264    9.85   2.88   14.73   1.73   16.27  1.22   20.89   1.25    7.77
# 342  342     NaN    NaN     NaN    NaN   32.54  2.65   55.06   2.81   38.94
#
#       tarw type
# 58    8.93   SW
# 56    7.69   SW
# ...

# %%
###Statistical  -mean,median,std,min,max etc

# %%
data
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
data["huml"].idxmax()  #maximun index
# Out:
# 58

# %%
data["huml"].idxmin()
# Out:
# 264

# %%
data["huml"].argmax()
# Out:
# 58

# %%
data["huml"].min()
# Out:
# 9.85

# %%
data["huml"].max()
# Out:
# 420.0

# %%
data["huml"].std()
# Out:
# 53.834548915405946

# %%
data.iloc[:,-3:-1].sum()  #coloumn wise addition
# Out:
# tarl    16437.36
# tarw     1227.68
# dtype: float64

# %%
data.iloc[:,-3:-1].sum(axis=1)  #row wise addition
# Out:
# 0      42.54
# 1      45.51
# 2      41.65
# 3      39.19
# 4      35.01
#        ...
# 415    23.14
# 416    24.75
# 417    24.07
# 418    27.22
# 419    22.74
# Length: 420, dtype: float64

# %% [markdown]
# ### Practice on Income Dataset
# - Combined Average Income of all states from 2005 to 2013
# - State with highest average income in the last three years
# - State with lowest average income from 2007 to 2010(inclusive)
# - Print the list of all states in the same line with average income less than California
# - Print the names of states based on descending order of income in the year 2009
# - State with the lowest recorded income from 2005 to 2013

# %%
income=pd.read_csv("Income.csv")
income
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
#Combined Average Income of all states from 2005 to 2013
a=income.iloc[:,2:].mean()

# %%
a.mean()
# Out:
# 48525.42222222223

# %%
#State with highest average income in the last three years

# %%
income=income.set_index("State")
income.iloc[:,-3:].mean(1).idxmax()
# Out:
# 'Alaska'

# %%
# State with lowest average income from 2007 to 2010(inclusive)

# %%
income
# Out:
#                 GEOID   2005   2006   2007   2008   2009   2010   2011   2012  \
# State
# Alabama     04000US01  37150  37952  42212  44476  39980  40933  42590  43464
# Alaska      04000US02  55891  56418  62993  63989  61604  57848  57431  63648
# Arizona     04000US04  45245  46657  47215  46914  45739  46896  48621  47044
# Arkansas    04000US05  36658  37057  40795  39586  36538  38587  41302  39018
# California  04000US06  51755  55319  55734  57014  56134  54283  53367  57020
#
#              2013
# State
# Alabama     41381
# Alaska      61137
# Arizona     50602
# Arkansas    39919
# California  57528

# %%
income.iloc[:,3:7].mean(1).idxmin()
# Out:
# 'Arkansas'

# %% [markdown]
# #### Print the list of all states in the same line with average income less than California

# %%
avg=income.iloc[:,1:].mean(1)
avg
# Out:
# State
# Alabama       41126.444444
# Alaska        60106.555556
# Arizona       47214.777778
# Arkansas      38828.888889
# California    55350.444444
# dtype: float64

# %%
avg['California']
# Out:
# 55350.444444444445

# %%
income[avg<avg['California']]
# Out:
#               GEOID   2005   2006   2007   2008   2009   2010   2011   2012  \
# State
# Alabama   04000US01  37150  37952  42212  44476  39980  40933  42590  43464
# Arizona   04000US04  45245  46657  47215  46914  45739  46896  48621  47044
# Arkansas  04000US05  36658  37057  40795  39586  36538  38587  41302  39018
#
#            2013
# State
# Alabama   41381
# Arizona   50602
# Arkansas  39919

# %%
list(income[avg<avg['California']].index)
# Out:
# ['Alabama', 'Arizona', 'Arkansas']

# %%
a=(1,2,3)

# %%
list(a)
# Out:
# [1, 2, 3]

# %%
#### Plotting
import matplotlib.pyplot as plt

# %%
income.plot()
plt.show()

# %%
income
# Out:
#                 GEOID   2005   2006   2007   2008   2009   2010   2011   2012  \
# State
# Alabama     04000US01  37150  37952  42212  44476  39980  40933  42590  43464
# Alaska      04000US02  55891  56418  62993  63989  61604  57848  57431  63648
# Arizona     04000US04  45245  46657  47215  46914  45739  46896  48621  47044
# Arkansas    04000US05  36658  37057  40795  39586  36538  38587  41302  39018
# California  04000US06  51755  55319  55734  57014  56134  54283  53367  57020
#
#              2013
# State
# Alabama     41381
# Alaska      61137
# Arizona     50602
# Arkansas    39919
# California  57528

# %%
income["2014"]=[1,2,3,4,5]

# %%
income
# Out:
#                 GEOID   2005   2006   2007   2008   2009   2010   2011   2012  \
# State
# Alabama     04000US01  37150  37952  42212  44476  39980  40933  42590  43464
# Alaska      04000US02  55891  56418  62993  63989  61604  57848  57431  63648
# Arizona     04000US04  45245  46657  47215  46914  45739  46896  48621  47044
# Arkansas    04000US05  36658  37057  40795  39586  36538  38587  41302  39018
# California  04000US06  51755  55319  55734  57014  56134  54283  53367  57020
#
#              2013  2014
# State
# Alabama     41381     1
# Alaska      61137     2
# Arizona     50602     3
# Arkansas    39919     4
# California  57528     5

# %% [markdown]
# ## Saving

# %%
income.to_csv("modifiedincome.csv")

# %%
income.to_excel("modifiedincome.xlsx")

# %% [markdown]
# # Cleaning data in Python
#
#
# * NaN : not a number -- special floating-point value
# * Working with duplicates and missing values
#     * isnull()
#     * notnull()
#     * dropna()
#     * fillna()
#     * replace()
# * Which values should be replaced with missing values based on data identifying and eliminating outliers
#
# * Dropping duplicate data
#
#
#
# #### Identifying and Eliminating Outliers
# * Outliers are observations that are significantly different from other data points
# * Outliers can adversely affect the training process of a machine learning algorithm, resulting in a loss of accuracy.
# * Need to use the mathematical formula and retrieve the outlier data.
#
#      **interquartile range(IQR) = Q3(quantile(0.75)) − Q1(quantile(0.25))**
#      ![boxplot](box.png)

# %%
emp=pd.read_csv('employe.csv')
emp.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
emp.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
emp.shape
# Out:
# (1000, 8)

# %%
emp.notnull().sum()
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# dtype: int64

# %%
emp.dropna()  #delete all the rows which has null values
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
emp.dropna(axis=1) #delete all the rows which has null values
# Out:
#      Start Date Last Login Time  Salary  Bonus %
# 0      8/6/1993        12:42 PM   97308    6.945
# 1     3/31/1996         6:53 AM   61933    4.170
# 2     4/23/1993        11:17 AM  130590   11.858
# 3      3/4/2005         1:00 PM  138705    9.340
# 4     1/24/1998         4:47 PM  101004    1.389
# ..          ...             ...     ...      ...
# 995  11/23/2014         6:09 AM  132483   16.655
# 996   1/31/1984         6:30 AM   42392   19.675
# 997   5/20/2013        12:39 PM   96914    1.421
# 998   4/20/2013         4:45 PM   60500   11.985
# 999   5/15/2012         6:24 PM  129949   10.169
#
# [1000 rows x 4 columns]

# %%
#we can fill Nan values with constant,mean,median,replace etc

# %%
emp['Gender'].fillna("Not Mentioned",inplace=True)

# %%
emp['Team'].fillna(method='pad')
# Out:
# 0                 Marketing
# 1                 Marketing
# 2                   Finance
# 3                   Finance
# 4           Client Services
#                ...
# 995            Distribution
# 996                 Finance
# 997                 Product
# 998    Business Development
# 999                   Sales
# Name: Team, Length: 1000, dtype: object

# %%
emp['First Name'].fillna(method='bfill')
# Out:
# 0      Douglas
# 1       Thomas
# 2        Maria
# 3        Jerry
# 4        Larry
#         ...
# 995      Henry
# 996    Phillip
# 997    Russell
# 998      Larry
# 999     Albert
# Name: First Name, Length: 1000, dtype: object

# %%
emp['Senior Management'].fillna(0)
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Senior Management, Length: 1000, dtype: object

# %%
emp.isnull().sum()
# Out:
# First Name           67
# Gender                0
# Start Date            0
# Last Login Time       0
# Salary                0
# Bonus %               0
# Senior Management    67
# Team                 43
# dtype: int64

# %%
emp["Gender"].unique()emp['First Name'].fillna(method='bfill')
# Out:
# array(['Male', 'Female', 'Not Mentioned'], dtype=object)

# %%
emp["Gender"].replace('Male',0,inplace=True)
emp["Gender"].replace('Female',1,inplace=True)
emp["Gender"].replace('Not Mentioned',-1,inplace=True)
emp["Gender"]
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 995   -1
# 996    0
# 997    0
# 998    0
# 999    0
# Name: Gender, Length: 1000, dtype: int64

# %%
import numpy as np
emp.replace(np.NaN,0)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       0    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas       0   3/31/1996         6:53 AM   61933    4.170
# 2        Maria       1   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       0    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       0   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry      -1  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       0   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       0   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       0   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       0   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                     0
# ...

# %% [markdown]
# ### Outliers

# %%
adv=pd.read_csv("Advertising.csv")
adv
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
#import seaborn as sns
adv.plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### interquartile range(IQR) = Q3(quantile(0.75)) − Q1(quantile(0.25))

# %%
Q3=adv.quantile(0.75)
Q1=adv.quantile(0.25)
IQR=Q3-Q1
IQR
# Out:
# TV           144.450
# radio         26.550
# newspaper     32.350
# sales          7.025
# dtype: float64

# %%
outliers_data= adv[((adv<(Q1-1.5*IQR)) | (adv>(Q3+1.5*IQR))).any(axis=1)]

# %%
outliers_data
# Out:
#         TV  radio  newspaper  sales
# 16    67.8   36.6      114.0   12.5
# 101  296.4   36.3      100.9   23.8

# %%
filter_data=adv[~((adv<(Q1-1.5*IQR)) | (adv>(Q3+1.5*IQR))).any(axis=1)]

# %%
filter_data
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [198 rows x 4 columns]

# %%
filter_data.plot(kind="box")
# Out:
# <AxesSubplot:>
